# %%
import cv2
import numpy as np
# %matplotlib inline
from PIL import Image
import matplotlib.pyplot as plt
import scipy.misc
from skimage import data
from skimage import filters
from skimage import exposure
import numpy.ma as ma


img = cv2.imread('C:/Users/user/Documents/DIP/DIP3E_Original_Images_CH09/Fig0935(a)(ckt_board_section).tif',0)
plt.imshow(img)
plt.gray()
plt.show()

# %%
erosion = cv2.erode(img,np.ones((3,3),dtype=np.uint8))
plt.imshow(erosion)
plt.show()

# %%
dilation = cv2.dilate(img,np.ones((3,3),dtype=np.uint8))
plt.imshow(dilation)
plt.show()
